# %%
# Confeccionar el núvol de paraules
# Dr Juan Huguet
# AA - MUSI 21 22

import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
words_dict = {
    "Aprendizaje Automático": 10,
    "Juan Huguet": 20,
    "MUSI": 10,
    "UIB": 14,
    "Aula Digital": 13,
    "21 22": 10,
    "Stay safe": 15,
    "features": 25,
    "world cloud": 5,
    "workshop":3,
    "Big Data": 12,
    "analítica": 6,
    "revenue": 24,
    "zoom": 8,
    "entregable": 12,
    "descenso gradiente": 10,
    "DAG": 14,
    "Machine Learning": 28,
    "modelo": 20,
    "productivizar": 20,
    "sklearn": 12,
    "git": 8,
    "pull": 8, 
    ".ipynb": 9,
    "conda": 3,
    "anaconda": 3,
    "Thanks you": 18
}

    # i per acabar, generam el núvol de duples

WC_height = 1000
WC_width = 1500
WC_max_words = 100

wordCloud = WordCloud(background_color="white", max_words=WC_max_words, 
                      height=WC_height, width=WC_width, random_state=42)
wordCloud.generate_from_frequencies(words_dict)
    
# el representam
plt.figure(figsize=(10,10))
plt.imshow(wordCloud, interpolation='bilinear')
plt.axis("off")
#plt.title("Thanks you, Juan!")
plt.savefig("wc-juan.png")
plt.show()
