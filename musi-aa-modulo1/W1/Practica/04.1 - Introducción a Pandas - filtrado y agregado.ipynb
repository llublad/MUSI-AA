# %% [markdown]
# # Introducción a pandas

# %% [markdown]
# Filtrar y agregar son de las acciones más recurrentes a la hora de manipular sets de datos. Veremos como  `pandas` nos permite hacer uso de una sintaxis simple para estas dos acciones.

# %% [markdown]
# ## Cargar datos y primera inspección

# %% [markdown]
# ## Filtrar

# %%
import pandas as pd

# %%
df = pd.read_csv('data/iris_dataset.csv')

# %%
df
# Out:
#     registry_id  sepal_length_cm  sepal_width_cm  petal_length_cm  \
# 0          b5d1              5.1             3.5              1.4
# 1          d54f              4.9             3.0              1.4
# 2          9c8a              4.7             3.2              1.3
# 3          0758              4.6             3.1              1.5
# 4          69cb              5.0             3.6              1.4
# ..          ...              ...             ...              ...
# 145        fafe              6.7             3.0              5.2
# 146        5fdb              6.3             2.5              5.0
# 147        3fad              6.5             3.0              5.2
# 148        38e9              6.2             3.4              5.4
# 149        2466              5.9             3.0              5.1
#
#      petal_width_cm      iris_class
# 0               0.2     Iris-setosa
# 1               0.2     Iris-setosa
# 2               0.2     Iris-setosa
# ...

# %%
df.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       150.000000      150.000000       150.000000      150.000000
# mean          5.843333        3.054000         3.758667        1.198667
# std           0.828066        0.433594         1.764420        0.763161
# min           4.300000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.300000
# 50%           5.800000        3.000000         4.350000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
df
# Out:
#     registry_id  sepal_length_cm  sepal_width_cm  petal_length_cm  \
# 0          b5d1              5.1             3.5              1.4
# 1          d54f              4.9             3.0              1.4
# 2          9c8a              4.7             3.2              1.3
# 3          0758              4.6             3.1              1.5
# 4          69cb              5.0             3.6              1.4
# ..          ...              ...             ...              ...
# 145        fafe              6.7             3.0              5.2
# 146        5fdb              6.3             2.5              5.0
# 147        3fad              6.5             3.0              5.2
# 148        38e9              6.2             3.4              5.4
# 149        2466              5.9             3.0              5.1
#
#      petal_width_cm      iris_class
# 0               0.2     Iris-setosa
# 1               0.2     Iris-setosa
# 2               0.2     Iris-setosa
# ...

# %%
df['sepal_length_cm'].between(4, 5)
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: sepal_length_cm, Length: 150, dtype: bool

# %%
mask = df['sepal_length_cm'].between(4, 5)

# %%
df[mask]
# Out:
#     registry_id  sepal_length_cm  sepal_width_cm  petal_length_cm  \
# 1          d54f              4.9             3.0              1.4
# 2          9c8a              4.7             3.2              1.3
# 3          0758              4.6             3.1              1.5
# 4          69cb              5.0             3.6              1.4
# 6          b71e              4.6             3.4              1.4
# 7          8cac              5.0             3.4              1.5
# 8          44a0              4.4             2.9              1.4
# 9          81ba              4.9             3.1              1.5
# 11         d31a              4.8             3.4              1.6
# 12         8b29              4.8             3.0              1.4
# 13         2d87              4.3             3.0              1.1
# 22         71a6              4.6             3.6              1.0
# 24         a021              4.8             3.4              1.9
# ...

# %%
mask_petal = df['petal_width_cm'].between(0,1)

# %%
df[mask & mask_petal]
# Out:
#    registry_id  sepal_length_cm  sepal_width_cm  petal_length_cm  \
# 1         d54f              4.9             3.0              1.4
# 2         9c8a              4.7             3.2              1.3
# 3         0758              4.6             3.1              1.5
# 4         69cb              5.0             3.6              1.4
# 6         b71e              4.6             3.4              1.4
# 7         8cac              5.0             3.4              1.5
# 8         44a0              4.4             2.9              1.4
# 9         81ba              4.9             3.1              1.5
# 11        d31a              4.8             3.4              1.6
# 12        8b29              4.8             3.0              1.4
# 13        2d87              4.3             3.0              1.1
# 22        71a6              4.6             3.6              1.0
# 24        a021              4.8             3.4              1.9
# ...

# %%
df[mask | mask_petal]
# Out:
#     registry_id  sepal_length_cm  sepal_width_cm  petal_length_cm  \
# 0          b5d1              5.1             3.5              1.4
# 1          d54f              4.9             3.0              1.4
# 2          9c8a              4.7             3.2              1.3
# 3          0758              4.6             3.1              1.5
# 4          69cb              5.0             3.6              1.4
# 5          1d7d              5.4             3.9              1.7
# 6          b71e              4.6             3.4              1.4
# 7          8cac              5.0             3.4              1.5
# 8          44a0              4.4             2.9              1.4
# 9          81ba              4.9             3.1              1.5
# 10         810f              5.4             3.7              1.5
# 11         d31a              4.8             3.4              1.6
# 12         8b29              4.8             3.0              1.4
# ...

# %%
df.head()
# Out:
#   registry_id  sepal_length_cm  sepal_width_cm  petal_length_cm  \
# 0        b5d1              5.1             3.5              1.4
# 1        d54f              4.9             3.0              1.4
# 2        9c8a              4.7             3.2              1.3
# 3        0758              4.6             3.1              1.5
# 4        69cb              5.0             3.6              1.4
#
#    petal_width_cm   iris_class
# 0             0.2  Iris-setosa
# 1             0.2  Iris-setosa
# 2             0.2  Iris-setosa
# 3             0.2  Iris-setosa
# 4             0.2  Iris-setosa

# %%
df[(df['iris_class'] == 'Iris-setosa') & (df['sepal_length_cm'] < 5)]
# Out:
#    registry_id  sepal_length_cm  sepal_width_cm  petal_length_cm  \
# 1         d54f              4.9             3.0              1.4
# 2         9c8a              4.7             3.2              1.3
# 3         0758              4.6             3.1              1.5
# 6         b71e              4.6             3.4              1.4
# 8         44a0              4.4             2.9              1.4
# 9         81ba              4.9             3.1              1.5
# 11        d31a              4.8             3.4              1.6
# 12        8b29              4.8             3.0              1.4
# 13        2d87              4.3             3.0              1.1
# 22        71a6              4.6             3.6              1.0
# 24        a021              4.8             3.4              1.9
# 29        37f3              4.7             3.2              1.6
# 30        954e              4.8             3.1              1.6
# ...

# %% [markdown]
# ## Agregar

# %% [markdown]
# ![split-apply-combine](./img/4-pandas/groupby-example.png)

# %%
df.groupby('iris_class')[['sepal_length_cm', 'sepal_width_cm']].mean()
# Out:
#                  sepal_length_cm  sepal_width_cm
# iris_class
# Iris-setosa                5.006           3.418
# Iris-versicolor            5.936           2.770
# Iris-virginica             6.588           2.974
